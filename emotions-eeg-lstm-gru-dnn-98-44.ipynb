# %% [markdown]
# # **1- Packages**

# %%
# %matplotlib inline

import warnings
import itertools    
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from scikeras.wrappers import KerasClassifier
from keras.layers import Dense, Flatten, LSTM, Input, Dropout, BatchNormalization, GRU
from keras import Model
from keras.models import load_model
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from keras.optimizers import Adam



sns.set_style('dark')

warnings.filterwarnings('ignore')

# %% [markdown]
# # **2- Data Preparation & EDA**

# %%
df = pd.read_csv('emotions.csv')
df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
#    fft_744_b  fft_745_b  fft_746_b  fft_747_b  fft_748_b  fft_749_b     label
# 0       23.5     -215.0     280.00    -162.00    -162.00     280.00  NEGATIVE
# 1      -23.3      182.0       2.57     -31.60     -31.60       2.57   NEUTRAL
# 2      462.0     -267.0     281.00    -148.00    -148.00     281.00  POSITIVE
# 3      299.0      132.0     -12.40       9.53       9.53     -12.40  POSITIVE
# 4       12.0      119.0     -17.60      23.90      23.90     -17.60   NEUTRAL
#
# [5 rows x 2549 columns]

# %%
# Checking for missing values
for col in df.columns:
    if(df[col].isnull().sum()>0):
        print(col)
# NO missing value

# %%
print(f'Classes are almost balanced. We can get away with the difference.\n{df.label.value_counts()}')
df.label.value_counts().plot(kind='bar', color='tab:blue', title='Label')
# Out:
# Classes are almost balanced. We can get away with the difference.
# label
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: count, dtype: int64
# <Axes: title={'center': 'Label'}, xlabel='label'>

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, dpi=200, figsize=(24, 12))

df.loc[0, 'fft_0_b':'fft_749_b'].plot(title='\"fft_0_b\" Through \"fft_749_b\" -- 1', color='tab:blue', ax=axes[0])
df.loc[10, 'fft_0_b':'fft_749_b'].plot(title='\"fft_0_b\" Through \"fft_749_b\" -- 10', color='tab:red', ax=axes[1])
df.loc[30, 'fft_0_b':'fft_749_b'].plot(title='\"fft_0_b\" Through \"fft_749_b\" -- 30', color='tab:green', ax=axes[2])

plt.subplots_adjust(left=0.1, bottom=0.1, 
                    right=0.9, top=0.9, 
                    wspace=0.4, hspace=0.4)

# %%
plt.figure(dpi=200, figsize=(24, 6))


plt.plot(df.loc[0, 'fft_0_b':'fft_749_b'], label='Sample 0', color='tab:red', alpha=.5)
plt.plot(df.loc[100, 'fft_0_b':'fft_749_b'], label='Sample 100', color='tab:blue', alpha=.8)
plt.plot(df.loc[200, 'fft_0_b':'fft_749_b'], label='Sample 200', color='black', alpha=.5)


plt.xticks(np.arange(0, len(df.loc[0, 'fft_0_b':'fft_749_b']) + 1, 100), rotation=45)
plt.legend(loc='best')

plt.show()

# %%
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])
df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
#    fft_744_b  fft_745_b  fft_746_b  fft_747_b  fft_748_b  fft_749_b  label
# 0       23.5     -215.0     280.00    -162.00    -162.00     280.00      0
# 1      -23.3      182.0       2.57     -31.60     -31.60       2.57      1
# 2      462.0     -267.0     281.00    -148.00    -148.00     281.00      2
# 3      299.0      132.0     -12.40       9.53       9.53     -12.40      2
# 4       12.0      119.0     -17.60      23.90      23.90     -17.60      1
#
# [5 rows x 2549 columns]

# %%
Y = df['label'].copy()
X = df.drop('label', axis=1).copy()

X_train, x_test, Y_train, y_test = train_test_split(X, Y,random_state=111, test_size=0.3)
X_train, x_val, Y_train, y_val=train_test_split(X_train, Y_train, random_state=111, test_size=0.3)

# %%
X_train = np.array(X_train).reshape((X_train.shape[0],X_train.shape[1],1))
x_test = np.array(x_test).reshape((x_test.shape[0], x_test.shape[1],1))

Y_train = pd.get_dummies(Y_train)
y_test = pd.get_dummies(y_test)
y_val = pd.get_dummies(y_val)

# %% [markdown]
# # **3- Modeling**

# %% [markdown]
# ## **3.1 LSTM**

# %%
i_lstm = Input(shape=(X_train.shape[1], 1))

x_lstm = LSTM(256, return_sequences=True)(i_lstm)
x_lstm = Flatten()(x_lstm)
y_lstm = Dense(3, activation='softmax')(x_lstm)

model_lstm = Model(i_lstm, y_lstm)

model_lstm.summary()
# Out:
# 2024-12-02 14:14:03.083678: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-12-02 14:14:03.083712: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-12-02 14:14:03.083719: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-12-02 14:14:03.083948: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-02 14:14:03.083972: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 2548, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 2548, 256)      │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 652288)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │     1,956,867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,221,059 (8.47 MB)
#  Trainable params: 2,221,059 (8.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = Adam(learning_rate=0.001)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)
mc = ModelCheckpoint('./best_lstm_model.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
lr_schedule = LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
                                    
model_lstm.compile(optimizer=adam,
                  loss=['categorical_crossentropy'],
                  metrics=['accuracy'])
        
lstm_h = model_lstm.fit(X_train, Y_train,
                   batch_size=32,
                   validation_data=(x_val, y_val),
                   epochs=50,
                   callbacks=[es, mc, lr_schedule])
# Out:
# Epoch 1/50
# 2024-12-02 14:14:28.976317: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 898ms/step - accuracy: 0.7295 - loss: 13.3799
# Epoch 1: val_accuracy improved from -inf to 0.87500, saving model to ./best_lstm_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.7318 - loss: 13.2474 - val_accuracy: 0.8750 - val_loss: 7.1421 - learning_rate: 0.0010
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9210 - loss: 2.8585
# Epoch 2: val_accuracy did not improve from 0.87500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9211 - loss: 2.8556 - val_accuracy: 0.8482 - val_loss: 3.9145 - learning_rate: 9.0484e-04
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9470 - loss: 1.1116
# Epoch 3: val_accuracy improved from 0.87500 to 0.93527, saving model to ./best_lstm_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9476 - loss: 1.0948 - val_accuracy: 0.9353 - val_loss: 2.1398 - learning_rate: 8.1873e-04
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9845 - loss: 0.2136
# Epoch 4: val_accuracy improved from 0.93527 to 0.95089, saving model to ./best_lstm_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9847 - loss: 0.2094 - val_accuracy: 0.9509 - val_loss: 1.5507 - learning_rate: 7.4082e-04
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9954 - loss: 0.0317
# Epoch 5: val_accuracy did not improve from 0.95089
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9954 - loss: 0.0332 - val_accuracy: 0.9330 - val_loss: 2.0148 - learning_rate: 6.7032e-04
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.9962 - loss: 0.0199
# Epoch 6: val_accuracy improved from 0.95089 to 0.96429, saving model to ./best_lstm_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 719ms/step - accuracy: 0.9962 - loss: 0.0199 - val_accuracy: 0.9643 - val_loss: 1.2947 - learning_rate: 6.0653e-04
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 9.7071e-04
# Epoch 7: val_accuracy improved from 0.96429 to 0.97098, saving model to ./best_lstm_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 245ms/step - accuracy: 1.0000 - loss: 9.5817e-04 - val_accuracy: 0.9710 - val_loss: 1.2159 - learning_rate: 5.4881e-04
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9997 - loss: 0.0016
# Epoch 8: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9621 - val_loss: 1.4442 - learning_rate: 4.9659e-04
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9975 - loss: 0.0268
# Epoch 9: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - accuracy: 0.9976 - loss: 0.0263 - val_accuracy: 0.9621 - val_loss: 1.3412 - learning_rate: 4.4933e-04
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 1.0000 - loss: 5.8074e-07
# Epoch 10: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 257ms/step - accuracy: 1.0000 - loss: 5.6937e-07 - val_accuracy: 0.9665 - val_loss: 1.2916 - learning_rate: 4.0657e-04
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 1.2336e-10
# Epoch 11: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 1.0000 - loss: 1.3316e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 3.6788e-04
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 3.6212e-10
# Epoch 12: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 245ms/step - accuracy: 1.0000 - loss: 3.6155e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 3.3287e-04
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 1.0000 - loss: 1.3848e-09
# Epoch 13: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 246ms/step - accuracy: 1.0000 - loss: 1.3542e-09 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 3.0119e-04
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 1.8335e-10
# Epoch 14: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - accuracy: 1.0000 - loss: 1.8804e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 2.7253e-04
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 1.3490e-10
# Epoch 15: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - accuracy: 1.0000 - loss: 1.4101e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 2.4660e-04
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 1.0000 - loss: 6.1156e-10
# Epoch 16: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - accuracy: 1.0000 - loss: 6.0365e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 2.2313e-04
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 1.0000 - loss: 3.9291e-10
# Epoch 17: val_accuracy did not improve from 0.97098
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - accuracy: 1.0000 - loss: 3.9143e-10 - val_accuracy: 0.9665 - val_loss: 1.2931 - learning_rate: 2.0190e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
acc = lstm_h.history['accuracy']
val_acc = lstm_h.history['val_accuracy']

loss = lstm_h.history['loss']
val_loss = lstm_h.history['val_loss']


plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('LSTM - Training & Validation Acc.', fontsize=16, weight='bold')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('LSTM - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

# %%
lstm_best = load_model('./best_lstm_model.h5')
lstm_acc = lstm_best.evaluate(x_test, y_test, verbose=0)[1]
print("Test Acc.: {:.3f}%".format(lstm_acc * 100))
# Out:
# Test Acc.: 97.500%

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), lstm_best.predict(x_test))))
y_test = y_test.idxmax(axis=1)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       190
#            1       1.00      0.98      0.99       231
#            2       0.95      0.98      0.96       219
#
#     accuracy                           0.97       640
#    macro avg       0.98      0.97      0.97       640
# weighted avg       0.98      0.97      0.98       640

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

cnf_matrix = cm
np.set_printoptions(precision=2)

plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['Negative', 'Neutral', 'Positive'], normalize=True,
                      title='LSTM - Normalized Confusion Matrix')
plt.show()
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## **3.2 GRU**

# %%
i_gru = Input(shape=(X_train.shape[1], 1))

x_gru = GRU(256, return_sequences=True)(i_gru)
x_gru = Flatten()(x_gru)
y_gru = Dense(3, activation='softmax')(x_gru)

model_gru = Model(i_gru, y_gru)

model_gru.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 2548, 1)]         0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 2548, 256)         198912
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 652288)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1956867
# =================================================================
# Total params: 2,155,779
# Trainable params: 2,155,779
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate=0.001)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)
mc = ModelCheckpoint('./best_gru_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
lr_schedule = LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
                                    
model_gru.compile(optimizer=adam,
                  loss=['categorical_crossentropy'],
                  metrics=['accuracy'])
        
gru_h = model_gru.fit(X_train, Y_train,
                   batch_size=32,
                   validation_data=(x_val, y_val),
                   epochs=50,
                   callbacks=[es, mc, lr_schedule])
# Out:
# 2022-08-01 06:55:30.940955: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 33/33 [==============================] - 7s 172ms/step - loss: 30.4880 - accuracy: 0.7720 - val_loss: 14.7857 - val_accuracy: 0.8884
#
# Epoch 00001: val_accuracy improved from -inf to 0.88839, saving model to ./best_gru_model.h5
# Epoch 2/50
# 33/33 [==============================] - 5s 164ms/step - loss: 9.3174 - accuracy: 0.9071 - val_loss: 7.2312 - val_accuracy: 0.8415
#
# Epoch 00002: val_accuracy did not improve from 0.88839
# Epoch 3/50
# 33/33 [==============================] - 6s 179ms/step - loss: 1.8030 - accuracy: 0.9588 - val_loss: 3.4468 - val_accuracy: 0.9241
#
# Epoch 00003: val_accuracy improved from 0.88839 to 0.92411, saving model to ./best_gru_model.h5
# Epoch 4/50
# 33/33 [==============================] - 5s 161ms/step - loss: 1.0354 - accuracy: 0.9674 - val_loss: 3.6411 - val_accuracy: 0.9330
#
# Epoch 00004: val_accuracy improved from 0.92411 to 0.93304, saving model to ./best_gru_model.h5
# Epoch 5/50
# 33/33 [==============================] - 5s 160ms/step - loss: 1.0231 - accuracy: 0.9684 - val_loss: 2.3576 - val_accuracy: 0.9464
#
# Epoch 00005: val_accuracy improved from 0.93304 to 0.94643, saving model to ./best_gru_model.h5
# Epoch 6/50
# 33/33 [==============================] - 6s 170ms/step - loss: 0.8212 - accuracy: 0.9741 - val_loss: 9.0814 - val_accuracy: 0.9018
#
# Epoch 00006: val_accuracy did not improve from 0.94643
# Epoch 7/50
# 33/33 [==============================] - 6s 178ms/step - loss: 1.0456 - accuracy: 0.9741 - val_loss: 2.2947 - val_accuracy: 0.9643
#
# Epoch 00007: val_accuracy improved from 0.94643 to 0.96429, saving model to ./best_gru_model.h5
# Epoch 8/50
# 33/33 [==============================] - 6s 182ms/step - loss: 0.8774 - accuracy: 0.9780 - val_loss: 7.8719 - val_accuracy: 0.8728
#
# Epoch 00008: val_accuracy did not improve from 0.96429
# Epoch 9/50
# 33/33 [==============================] - 6s 180ms/step - loss: 0.2173 - accuracy: 0.9914 - val_loss: 2.6917 - val_accuracy: 0.9598
#
# Epoch 00009: val_accuracy did not improve from 0.96429
# Epoch 10/50
# 33/33 [==============================] - 5s 163ms/step - loss: 0.0129 - accuracy: 0.9990 - val_loss: 2.0701 - val_accuracy: 0.9688
#
# Epoch 00010: val_accuracy improved from 0.96429 to 0.96875, saving model to ./best_gru_model.h5
# Epoch 11/50
# 33/33 [==============================] - 5s 162ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1844 - val_accuracy: 0.9643
#
# Epoch 00011: val_accuracy did not improve from 0.96875
# Epoch 12/50
# 33/33 [==============================] - 6s 180ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1899 - val_accuracy: 0.9643
#
# Epoch 00012: val_accuracy did not improve from 0.96875
# Epoch 13/50
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00013: val_accuracy did not improve from 0.96875
# Epoch 14/50
# 33/33 [==============================] - 5s 161ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00014: val_accuracy did not improve from 0.96875
# Epoch 15/50
# 33/33 [==============================] - 5s 162ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00015: val_accuracy did not improve from 0.96875
# Epoch 16/50
# 33/33 [==============================] - 5s 163ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00016: val_accuracy did not improve from 0.96875
# Epoch 17/50
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00017: val_accuracy did not improve from 0.96875
# Epoch 18/50
# 33/33 [==============================] - 5s 164ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00018: val_accuracy did not improve from 0.96875
# Epoch 19/50
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
#
# Epoch 00019: val_accuracy did not improve from 0.96875
# Epoch 20/50
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.1901 - val_accuracy: 0.9643
# Restoring model weights from the end of the best epoch.
#
# Epoch 00020: val_accuracy did not improve from 0.96875
# Epoch 00020: early stopping

# %%
# Show History
acc = gru_h.history['accuracy']
val_acc = gru_h.history['val_accuracy']

loss = gru_h.history['loss']
val_loss = gru_h.history['val_loss']


plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('GRU - Training & Validation Acc.', fontsize=16, weight='bold')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('GRU - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

# %%
gru_best = load_model('./best_gru_model.h5')
gru_acc = gru_best.evaluate(x_test, y_test, verbose=0)[1]
print("Test Acc. GRU: {:.3f}%".format(gru_acc * 100))
# Out:
# Test Acc. GRU: 97.188%

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), gru_best.predict(x_test))))
y_test = y_test.idxmax(axis=1)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       190
#            1       0.98      0.98      0.98       231
#            2       0.96      0.95      0.96       219
#
#     accuracy                           0.97       640
#    macro avg       0.97      0.97      0.97       640
# weighted avg       0.97      0.97      0.97       640

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

cnf_matrix = cm
np.set_printoptions(precision=2)

plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['Negative', 'Neutral', 'Positive'], normalize=True,
                      title='GRU - Normalized Confusion Matrix')
plt.show()
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## **3.2 DNN**

# %%
Y = df['label'].copy()
X = df.drop('label', axis=1).copy()

X = StandardScaler().fit_transform(X)

X_train, x_test, Y_train, y_test = train_test_split(X, Y,random_state=111, test_size=0.3)
X_train, x_val, Y_train, y_val=train_test_split(X_train, Y_train, random_state=111, test_size=0.3)

Y_train = pd.get_dummies(Y_train)
y_test = pd.get_dummies(y_test)
y_val = pd.get_dummies(y_val)

# %%
i_dnn = Input(shape=(2548, ))

x_dnn = Dense(2548, activation='relu')(i_dnn)
x_dnn = BatchNormalization()(x_dnn)
x_dnn = Dropout(0.25)(x_dnn)

x_dnn = Dense(3822, activation='relu')(x_dnn)
x_dnn = BatchNormalization()(x_dnn)
x_dnn = Dropout(0.27)(x_dnn)

x_dnn = Dense(5096, activation='relu')(x_dnn)
x_dnn = BatchNormalization()(x_dnn)
x_dnn = Dropout(0.3)(x_dnn)

x_dnn = Dense(3822, activation='relu')(x_dnn)
x_dnn = BatchNormalization()(x_dnn)
x_dnn = Dropout(0.27)(x_dnn)

x_dnn = Dense(2548, activation='relu')(x_dnn)
x_dnn = BatchNormalization()(x_dnn)
x_dnn = Dropout(0.25)(x_dnn)

y_dnn = Dense(3, activation='softmax')(x_dnn)

dnn_model = Model(i_dnn, y_dnn)

dnn_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2548)]            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2548)              6494852
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2548)              10192
# _________________________________________________________________
# dropout (Dropout)            (None, 2548)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3822)              9742278
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3822)              15288
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3822)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5096)              19482008
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5096)              20384
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3822)              19480734
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3822)              15288
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3822)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2548)              9741004
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2548)              10192
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2548)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 7647
# =================================================================
# Total params: 65,019,867
# Trainable params: 64,984,195
# Non-trainable params: 35,672
# _________________________________________________________________

# %%
adam = Adam(learning_rate=0.001)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)
mc = ModelCheckpoint('./best_dnn_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
lr_schedule = LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
                                    
dnn_model.compile(optimizer=adam,
                  loss=['categorical_crossentropy'],
                  metrics=['accuracy'])
        
dnn_h = dnn_model.fit(X_train, Y_train,
                   batch_size=32,
                   validation_data=(x_val, y_val),
                   epochs=50,
                   callbacks=[es, mc, lr_schedule])
# Out:
# Epoch 1/50
# 33/33 [==============================] - 2s 20ms/step - loss: 1.8722 - accuracy: 0.8228 - val_loss: 73.7496 - val_accuracy: 0.5848
#
# Epoch 00001: val_accuracy improved from -inf to 0.58482, saving model to ./best_dnn_model.h5
# Epoch 2/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.3427 - accuracy: 0.8975 - val_loss: 9.6871 - val_accuracy: 0.8616
#
# Epoch 00002: val_accuracy improved from 0.58482 to 0.86161, saving model to ./best_dnn_model.h5
# Epoch 3/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.3352 - accuracy: 0.9004 - val_loss: 1.2572 - val_accuracy: 0.8750
#
# Epoch 00003: val_accuracy improved from 0.86161 to 0.87500, saving model to ./best_dnn_model.h5
# Epoch 4/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2074 - accuracy: 0.9224 - val_loss: 0.9448 - val_accuracy: 0.8929
#
# Epoch 00004: val_accuracy improved from 0.87500 to 0.89286, saving model to ./best_dnn_model.h5
# Epoch 5/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1808 - accuracy: 0.9406 - val_loss: 0.3244 - val_accuracy: 0.8973
#
# Epoch 00005: val_accuracy improved from 0.89286 to 0.89732, saving model to ./best_dnn_model.h5
# Epoch 6/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2062 - accuracy: 0.9310 - val_loss: 0.2619 - val_accuracy: 0.9219
#
# Epoch 00006: val_accuracy improved from 0.89732 to 0.92188, saving model to ./best_dnn_model.h5
# Epoch 7/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1897 - accuracy: 0.9339 - val_loss: 0.1939 - val_accuracy: 0.9442
#
# Epoch 00007: val_accuracy improved from 0.92188 to 0.94420, saving model to ./best_dnn_model.h5
# Epoch 8/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1406 - accuracy: 0.9473 - val_loss: 0.1839 - val_accuracy: 0.9330
#
# Epoch 00008: val_accuracy did not improve from 0.94420
# Epoch 9/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1025 - accuracy: 0.9636 - val_loss: 0.2481 - val_accuracy: 0.9174
#
# Epoch 00009: val_accuracy did not improve from 0.94420
# Epoch 10/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1218 - accuracy: 0.9598 - val_loss: 0.2759 - val_accuracy: 0.9286
#
# Epoch 00010: val_accuracy did not improve from 0.94420
# Epoch 11/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0970 - accuracy: 0.9693 - val_loss: 0.2277 - val_accuracy: 0.9152
#
# Epoch 00011: val_accuracy did not improve from 0.94420
# Epoch 12/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0847 - accuracy: 0.9732 - val_loss: 0.1416 - val_accuracy: 0.9643
#
# Epoch 00012: val_accuracy improved from 0.94420 to 0.96429, saving model to ./best_dnn_model.h5
# Epoch 13/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0429 - accuracy: 0.9856 - val_loss: 0.1460 - val_accuracy: 0.9621
#
# Epoch 00013: val_accuracy did not improve from 0.96429
# Epoch 14/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0717 - accuracy: 0.9761 - val_loss: 0.1552 - val_accuracy: 0.9531
#
# Epoch 00014: val_accuracy did not improve from 0.96429
# Epoch 15/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0283 - accuracy: 0.9933 - val_loss: 0.1272 - val_accuracy: 0.9598
#
# Epoch 00015: val_accuracy did not improve from 0.96429
# Epoch 16/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0423 - accuracy: 0.9904 - val_loss: 0.2689 - val_accuracy: 0.9241
#
# Epoch 00016: val_accuracy did not improve from 0.96429
# Epoch 17/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0949 - accuracy: 0.9780 - val_loss: 0.1955 - val_accuracy: 0.9286
#
# Epoch 00017: val_accuracy did not improve from 0.96429
# Epoch 18/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0308 - accuracy: 0.9904 - val_loss: 0.1226 - val_accuracy: 0.9688
#
# Epoch 00018: val_accuracy improved from 0.96429 to 0.96875, saving model to ./best_dnn_model.h5
# Epoch 19/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0167 - accuracy: 0.9933 - val_loss: 0.0972 - val_accuracy: 0.9754
#
# Epoch 00019: val_accuracy improved from 0.96875 to 0.97545, saving model to ./best_dnn_model.h5
# Epoch 20/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0240 - accuracy: 0.9962 - val_loss: 0.1283 - val_accuracy: 0.9576
#
# Epoch 00020: val_accuracy did not improve from 0.97545
# Epoch 21/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0168 - accuracy: 0.9933 - val_loss: 0.1051 - val_accuracy: 0.9799
#
# Epoch 00021: val_accuracy improved from 0.97545 to 0.97991, saving model to ./best_dnn_model.h5
# Epoch 22/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.0146 - accuracy: 0.9923 - val_loss: 0.1062 - val_accuracy: 0.9754
#
# Epoch 00022: val_accuracy did not improve from 0.97991
# Epoch 23/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0985 - val_accuracy: 0.9732
#
# Epoch 00023: val_accuracy did not improve from 0.97991
# Epoch 24/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0114 - accuracy: 0.9943 - val_loss: 0.1132 - val_accuracy: 0.9754
#
# Epoch 00024: val_accuracy did not improve from 0.97991
# Epoch 25/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.1038 - val_accuracy: 0.9754
#
# Epoch 00025: val_accuracy did not improve from 0.97991
# Epoch 26/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0402 - accuracy: 0.9904 - val_loss: 0.1000 - val_accuracy: 0.9777
#
# Epoch 00026: val_accuracy did not improve from 0.97991
# Epoch 27/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.1212 - val_accuracy: 0.9643
#
# Epoch 00027: val_accuracy did not improve from 0.97991
# Epoch 28/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 0.9923 - val_loss: 0.1248 - val_accuracy: 0.9688
#
# Epoch 00028: val_accuracy did not improve from 0.97991
# Epoch 29/50
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0995 - val_accuracy: 0.9821
# Restoring model weights from the end of the best epoch.
#
# Epoch 00029: val_accuracy improved from 0.97991 to 0.98214, saving model to ./best_dnn_model.h5
# Epoch 00029: early stopping

# %%
# Show History
acc = dnn_h.history['accuracy']
val_acc = dnn_h.history['val_accuracy']

loss = dnn_h.history['loss']
val_loss = dnn_h.history['val_loss']


plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('DNN - Training & Validation Acc.', fontsize=16, weight='bold')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('DNN - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

# %%
dnn_best = load_model('./best_dnn_model.h5')
dnn_acc = dnn_best.evaluate(x_test, y_test, verbose=0)[1]
print("Test Acc. DNN: {:.3f}%".format(dnn_acc * 100))
# Out:
# Test Acc. DNN: 98.438%

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), dnn_best.predict(x_test))))
y_test = y_test.idxmax(axis=1)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       190
#            1       0.99      0.99      0.99       231
#            2       0.97      0.98      0.98       219
#
#     accuracy                           0.98       640
#    macro avg       0.98      0.98      0.98       640
# weighted avg       0.98      0.98      0.98       640

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

cnf_matrix = cm
np.set_printoptions(precision=2)

plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['Negative', 'Neutral', 'Positive'], normalize=True,
                      title='DNN - Normalized Confusion Matrix')
plt.show()
# Out:
# Normalized confusion matrix

# %% [markdown]
# # **4- Conclusion**
# **1. In both cases (GRU & LSTM), *val_loss* seems to be stucked in local minima. I'm too lazy to go back and try to fix this, but for the DNN model, I'm going to scale the data just in case. Also, perhaps not all of the 2.5k features are needed, and therefore, using Mutual Information (MI) and choosing the top *N*% features might also improve the performance.**
#
# **2. The accuracy of models on the test set is as follows:**
#  + **DNN: 98.44%**
#  + **LSTM: 97.5%**
#  + **GRU: 97.18%**
#
# **3. Classification reports suggest that all models managed to generalize well, even though the classes are not perfectly balanced in each set**
#
# **4. Overall, the DNN model offered the best performance. The reason for this might be the fact that I used Z-Score (StandardScaler) for the DNN data. Finally, I believe the performance can also be improved a bit with further data processing and hyperparameter tuning**
